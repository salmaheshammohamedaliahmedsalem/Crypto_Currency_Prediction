# %%
pip install kaggle

# %%
# Out:
#   File "<ipython-input-10-c9506180c531>", line 1
#     kaggle competitions download -c child-mind-institute-detect-sleep-states
#            ^
# SyntaxError: invalid syntax
